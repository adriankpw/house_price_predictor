# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
# %matplotlib inline

# %% [markdown]
# ## Load Testing Data

# %%
test = pd.read_csv('./datasets/test.csv')

# %%
test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 0   NaN          NaN        0       4     2006        WD
# 1   NaN          NaN        0       8     2006        WD
# 2   NaN          NaN        0       9     2006        New
# 3   NaN          NaN        0       7     2007        WD
# 4   NaN          NaN        0       7     2009        WD
#
# [5 rows x 80 columns]

# %%
print(test.shape)
# Out:
# (879, 80)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 80 columns):
# Id                 879 non-null int64
# PID                879 non-null int64
# MS SubClass        879 non-null int64
# MS Zoning          879 non-null object
# Lot Frontage       719 non-null float64
# Lot Area           879 non-null int64
# Street             879 non-null object
# Alley              58 non-null object
# Lot Shape          879 non-null object
# Land Contour       879 non-null object
# Utilities          879 non-null object
# Lot Config         879 non-null object
# Land Slope         879 non-null object
# Neighborhood       879 non-null object
# Condition 1        879 non-null object
# Condition 2        879 non-null object
# Bldg Type          879 non-null object
# House Style        879 non-null object
# Overall Qual       879 non-null int64
# Overall Cond       879 non-null int64
# Year Built         879 non-null int64
# Year Remod/Add     879 non-null int64
# Roof Style         879 non-null object
# Roof Matl          879 non-null object
# Exterior 1st       879 non-null object
# Exterior 2nd       879 non-null object
# Mas Vnr Type       878 non-null object
# Mas Vnr Area       878 non-null float64
# Exter Qual         879 non-null object
# Exter Cond         879 non-null object
# Foundation         879 non-null object
# Bsmt Qual          854 non-null object
# Bsmt Cond          854 non-null object
# Bsmt Exposure      854 non-null object
# BsmtFin Type 1     854 non-null object
# BsmtFin SF 1       879 non-null int64
# BsmtFin Type 2     854 non-null object
# BsmtFin SF 2       879 non-null int64
# Bsmt Unf SF        879 non-null int64
# Total Bsmt SF      879 non-null int64
# Heating            879 non-null object
# Heating QC         879 non-null object
# Central Air        879 non-null object
# Electrical         878 non-null object
# 1st Flr SF         879 non-null int64
# 2nd Flr SF         879 non-null int64
# Low Qual Fin SF    879 non-null int64
# Gr Liv Area        879 non-null int64
# Bsmt Full Bath     879 non-null int64
# Bsmt Half Bath     879 non-null int64
# Full Bath          879 non-null int64
# Half Bath          879 non-null int64
# Bedroom AbvGr      879 non-null int64
# Kitchen AbvGr      879 non-null int64
# Kitchen Qual       879 non-null object
# TotRms AbvGrd      879 non-null int64
# Functional         879 non-null object
# Fireplaces         879 non-null int64
# Fireplace Qu       457 non-null object
# Garage Type        835 non-null object
# Garage Yr Blt      834 non-null float64
# Garage Finish      834 non-null object
# Garage Cars        879 non-null int64
# Garage Area        879 non-null int64
# Garage Qual        834 non-null object
# Garage Cond        834 non-null object
# Paved Drive        879 non-null object
# Wood Deck SF       879 non-null int64
# Open Porch SF      879 non-null int64
# Enclosed Porch     879 non-null int64
# 3Ssn Porch         879 non-null int64
# Screen Porch       879 non-null int64
# Pool Area          879 non-null int64
# Pool QC            4 non-null object
# Fence              172 non-null object
# Misc Feature       41 non-null object
# Misc Val           879 non-null int64
# Mo Sold            879 non-null int64
# Yr Sold            879 non-null int64
# Sale Type          879 non-null object
# dtypes: float64(3), int64(35), object(42)
# memory usage: 549.5+ KB

# %% [markdown]
# ## Filling up null values

# %%
test['Lot Frontage'].fillna(0, inplace = True)

# %%
test['Alley'].fillna('None', inplace = True)

# %%
test['Mas Vnr Type'].fillna('None', inplace = True)

# %%
test['Mas Vnr Area'].fillna(0, inplace = True)

# %%
test['Garage Type'].fillna('None', inplace = True)

# %%
test['Garage Yr Blt'].fillna(0, inplace = True)

# %%
test['Garage Finish'].fillna('None', inplace = True)

# %%
test['Garage Cars'].fillna(0, inplace = True)

# %%
test['Garage Area'].fillna(0, inplace = True)

# %%
test['Garage Qual'].fillna('None',inplace = True)

# %%
test['Garage Cond'].fillna('None',inplace = True)

# %%
test['Bsmt Qual'].fillna('None', inplace = True)

# %%
test['Bsmt Cond'].fillna('None', inplace = True)

# %%
test['Bsmt Exposure'].fillna('None', inplace = True)

# %%
test['BsmtFin Type 1'].fillna('None', inplace = True)

# %%
test['BsmtFin SF 1'].fillna(0, inplace = True)

# %%
test['BsmtFin Type 2'].fillna('None', inplace = True)

# %%
test['BsmtFin SF 2'].fillna(0, inplace = True)

# %%
test['Bsmt Unf SF'].fillna(0, inplace = True)

# %%
test['Total Bsmt SF'].fillna(0, inplace = True)

# %%
test['Bsmt Full Bath'].fillna(0, inplace = True)

# %%
test['Bsmt Half Bath'].fillna(0, inplace = True)

# %%
test['Fireplace Qu'].fillna('None', inplace = True)

# %%
test['Pool QC'].fillna('None', inplace = True)

# %%
test['Fence'].fillna('None', inplace = True)

# %%
test['Misc Feature'].fillna('None', inplace = True)

# %% [markdown]
# ## Convert categorical features to numerical features

# %%
test_categorical = test.select_dtypes(include = ['object'])

# %%
test_categorical.shape
# Out:
# (879, 42)

# %%
test_categorical.head(10).T
# Out:
#                       0        1        2        3        4        5        6  \
# MS Zoning            RM       RL       RL       RM       RL       RM       RM
# Street             Pave     Pave     Pave     Pave     Pave     Pave     Pave
# Alley              Grvl     None     None     None     None     None     None
# Lot Shape           Reg      IR1      IR1      Reg      IR1      Reg      Reg
# Land Contour        Lvl      Lvl      Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities        AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# Lot Config       Inside   Inside   Inside   Inside   Inside   Inside   Inside
# Land Slope          Gtl      Gtl      Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood    OldTown   Sawyer  Gilbert  OldTown    NAmes  MeadowV  OldTown
# Condition 1        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# Condition 2        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# Bldg Type        2fmCon   Duplex     1Fam     1Fam     1Fam   TwnhsE     1Fam
# House Style      2Story   1Story   2Story   1Story   1Story   2Story   1Story
# Roof Style        Gable    Gable    Gable    Gable    Gable    Gable    Gable
# Roof Matl       CompShg  CompShg  CompShg  CompShg  CompShg  CompShg  CompShg
# Exterior 1st    AsbShng  Plywood  VinylSd  Wd Sdng  Plywood  CemntBd  MetalSd
# Exterior 2nd    AsbShng  Plywood  VinylSd  Wd Sdng  Plywood  CmentBd  MetalSd
# Mas Vnr Type       None     None     None     None  BrkFace     None     None
# Exter Qual           TA       TA       Gd       Gd       TA       TA       TA
# Exter Cond           Fa       TA       TA       TA       TA       TA       TA
# Foundation        Stone   CBlock    PConc   CBlock   CBlock   CBlock   CBlock
# Bsmt Qual            Fa       Gd       Gd       TA       Gd       TA       TA
# Bsmt Cond            TA       TA       Gd       TA       TA       TA       TA
# Bsmt Exposure        No       No       Av       No       No       No       No
# BsmtFin Type 1      Unf      Unf      GLQ      Unf      BLQ      Rec      Unf
# BsmtFin Type 2      Unf      Unf      Unf      Unf      Unf      Unf      Unf
# Heating            GasA     GasA     GasA     GasA     GasA     GasA     GasA
# Heating QC           Gd       TA       Ex       TA       Gd       TA       TA
# Central Air           N        Y        Y        Y        Y        Y        Y
# Electrical        FuseP    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr
# Kitchen Qual         Fa       TA       Gd       TA       TA       TA       TA
# Functional          Typ      Typ      Typ      Typ      Typ      Typ      Typ
# Fireplace Qu       None     None       Gd     None       Gd     None     None
# Garage Type      Detchd   Attchd   Attchd   Detchd   Attchd   Attchd   Detchd
# Garage Finish       Unf      Fin      RFn      Unf      RFn      Unf      Unf
# Garage Qual          Po       TA       TA       Fa       TA       TA       TA
# Garage Cond          Po       TA       TA       TA       TA       TA       TA
# Paved Drive           Y        Y        Y        N        Y        Y        Y
# Pool QC            None     None     None     None     None     None     None
# Fence              None     None     None     None     None     None     None
# Misc Feature       None     None     None     None     None     None     None
# Sale Type           WD       WD       New      WD       WD       WD       WD
#
#                       7        8        9
# MS Zoning            RL       FV       RL
# Street             Pave     Pave     Pave
# Alley              None     Pave     None
# Lot Shape           IR1      Reg      Reg
# Land Contour        Lvl      Lvl      Lvl
# Utilities        AllPub   AllPub   AllPub
# Lot Config      CulDSac   Inside   Inside
# Land Slope          Mod      Gtl      Gtl
# Neighborhood    CollgCr  Somerst  Mitchel
# Condition 1        Norm     Norm     Norm
# Condition 2        Norm     Norm     Norm
# Bldg Type          1Fam   TwnhsE     1Fam
# House Style      1Story   2Story   1Story
# Roof Style        Gable    Gable    Gable
# Roof Matl       CompShg  CompShg  CompShg
# Exterior 1st    HdBoard  VinylSd  Plywood
# Exterior 2nd    Plywood  VinylSd  Plywood
# Mas Vnr Type       None     None     None
# Exter Qual           TA       Gd       TA
# Exter Cond           TA       TA       TA
# Foundation       CBlock    PConc   CBlock
# Bsmt Qual            Gd       Gd       TA
# Bsmt Cond            Gd       TA       TA
# Bsmt Exposure        Av       No       No
# BsmtFin Type 1      ALQ      Unf      ALQ
# BsmtFin Type 2      Unf      Unf      LwQ
# Heating            GasA     GasA     GasA
# Heating QC           TA       Ex       TA
# Central Air           Y        Y        Y
# Electrical        SBrkr    SBrkr    SBrkr
# Kitchen Qual         Gd       Gd       TA
# Functional          Typ      Typ      Typ
# Fireplace Qu       None     None       Fa
# Garage Type      Detchd   Attchd   Detchd
# Garage Finish       Unf      RFn      Unf
# Garage Qual          TA       TA       TA
# Garage Cond          TA       TA       TA
# Paved Drive           Y        Y        Y
# Pool QC            None     None     None
# Fence              None     None    MnPrv
# Misc Feature       None     None     None
# Sale Type           WD       WD       WD

# %%
test['Exter Qual'] = test['Exter Qual'].replace(['Ex','Gd','TA','Fa'], [5,4,3,2])

# %%
test['Exter Cond'] = test['Exter Cond'].replace(['Ex','Gd','TA','Fa','Po'], [5,4,3,2,1])

# %%
test['Bsmt Qual'] = test['Bsmt Qual'].replace(['Ex','Gd','TA','Fa','Po','None'], [5,4,3,2,1,0])

# %%
test['Bsmt Cond'] = test['Bsmt Cond'].replace(['Ex','Gd','TA','Fa','Po','None'], [5,4,3,2,1,0])

# %%
test['Bsmt Exposure'] = test['Bsmt Exposure'].replace(['Gd','Av','Mn','No','None'], [4,3,2,1,0])

# %%
test['BsmtFin Type 1'] = test['BsmtFin Type 1'].replace(['GLQ','ALQ','BLQ','Rec','LwQ','Unf','None'], [6,5,4,3,2,1,0])

# %%
test['BsmtFin Type 2'] = test['BsmtFin Type 2'].replace(['GLQ','ALQ','BLQ','Rec','LwQ','Unf','None'], [6,5,4,3,2,1,0])

# %%
test['Heating QC'] = test['Heating QC'].replace(['Ex','Gd','TA','Fa'], [5,4,3,2])

# %%
test['Kitchen Qual'] = test['Kitchen Qual'].replace(['Ex','Gd','TA','Fa','Po'], [5,4,3,2,1])

# %%
test['Garage Finish'] = test['Garage Finish'].replace(['Fin','RFn','Unf','None'], [3,2,1,0])

# %%
test['Garage Qual'] = test['Garage Qual'].replace(['Ex','Gd','TA','Fa','Po','None'], [5,4,3,2,1,0])

# %%
test['Garage Cond'] = test['Garage Cond'].replace(['Ex','Gd','TA','Fa','Po','None'], [5,4,3,2,1,0])

# %%
test['Fireplace Qu'] = test['Fireplace Qu'].replace(['Ex','Gd','TA','Fa','Po','None'], [5,4,3,2,1,0])

# %% [markdown]
# ## Removing columns

# %%
test.drop(columns = 'PID', inplace = True)

# %%
test['Pool QC'].value_counts()
# Out:
# None    875
# Ex        3
# TA        1
# Name: Pool QC, dtype: int64

# %%
# drop Pool QC column as there are only a few non-null values
test.drop(columns = 'Pool QC', inplace = True)

# %%
test_categorical = test.select_dtypes(include = ['object'])

# %%
test_categorical.shape
# Out:
# (879, 28)

# %%
test_categorical.head(10).T
# Out:
#                     0        1        2        3        4        5        6  \
# MS Zoning          RM       RL       RL       RM       RL       RM       RM
# Street           Pave     Pave     Pave     Pave     Pave     Pave     Pave
# Alley            Grvl     None     None     None     None     None     None
# Lot Shape         Reg      IR1      IR1      Reg      IR1      Reg      Reg
# Land Contour      Lvl      Lvl      Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities      AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# Lot Config     Inside   Inside   Inside   Inside   Inside   Inside   Inside
# Land Slope        Gtl      Gtl      Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood  OldTown   Sawyer  Gilbert  OldTown    NAmes  MeadowV  OldTown
# Condition 1      Norm     Norm     Norm     Norm     Norm     Norm     Norm
# Condition 2      Norm     Norm     Norm     Norm     Norm     Norm     Norm
# Bldg Type      2fmCon   Duplex     1Fam     1Fam     1Fam   TwnhsE     1Fam
# House Style    2Story   1Story   2Story   1Story   1Story   2Story   1Story
# Roof Style      Gable    Gable    Gable    Gable    Gable    Gable    Gable
# Roof Matl     CompShg  CompShg  CompShg  CompShg  CompShg  CompShg  CompShg
# Exterior 1st  AsbShng  Plywood  VinylSd  Wd Sdng  Plywood  CemntBd  MetalSd
# Exterior 2nd  AsbShng  Plywood  VinylSd  Wd Sdng  Plywood  CmentBd  MetalSd
# Mas Vnr Type     None     None     None     None  BrkFace     None     None
# Foundation      Stone   CBlock    PConc   CBlock   CBlock   CBlock   CBlock
# Heating          GasA     GasA     GasA     GasA     GasA     GasA     GasA
# Central Air         N        Y        Y        Y        Y        Y        Y
# Electrical      FuseP    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr
# Functional        Typ      Typ      Typ      Typ      Typ      Typ      Typ
# Garage Type    Detchd   Attchd   Attchd   Detchd   Attchd   Attchd   Detchd
# Paved Drive         Y        Y        Y        N        Y        Y        Y
# Fence            None     None     None     None     None     None     None
# Misc Feature     None     None     None     None     None     None     None
# Sale Type         WD       WD       New      WD       WD       WD       WD
#
#                     7        8        9
# MS Zoning          RL       FV       RL
# Street           Pave     Pave     Pave
# Alley            None     Pave     None
# Lot Shape         IR1      Reg      Reg
# Land Contour      Lvl      Lvl      Lvl
# Utilities      AllPub   AllPub   AllPub
# Lot Config    CulDSac   Inside   Inside
# Land Slope        Mod      Gtl      Gtl
# Neighborhood  CollgCr  Somerst  Mitchel
# Condition 1      Norm     Norm     Norm
# Condition 2      Norm     Norm     Norm
# Bldg Type        1Fam   TwnhsE     1Fam
# House Style    1Story   2Story   1Story
# Roof Style      Gable    Gable    Gable
# Roof Matl     CompShg  CompShg  CompShg
# Exterior 1st  HdBoard  VinylSd  Plywood
# Exterior 2nd  Plywood  VinylSd  Plywood
# Mas Vnr Type     None     None     None
# Foundation     CBlock    PConc   CBlock
# Heating          GasA     GasA     GasA
# Central Air         Y        Y        Y
# Electrical      SBrkr    SBrkr    SBrkr
# Functional        Typ      Typ      Typ
# Garage Type    Detchd   Attchd   Detchd
# Paved Drive         Y        Y        Y
# Fence            None     None    MnPrv
# Misc Feature     None     None     None
# Sale Type         WD       WD       WD

# %%
test_numerical = test.select_dtypes(exclude = ['object'])

# %%
test = test_numerical.merge(pd.get_dummies(test_categorical, drop_first = True),left_index = True, right_index = True)

# %%
test.to_csv('./datasets/test_cleaned.csv', index = False)

# %%
test.shape
# Out:
# (879, 200)
